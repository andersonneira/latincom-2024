# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import numpy as np
from sklearn import metrics
from sklearn.mixture import GaussianMixture
from sklearn_som.som import SOM
from sklearn.cluster import *
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from announce import *
from sklearn.decomposition import *
from sklearn.manifold import *
import time
start = time.time()
early_warning_url = "../data/early_warning_exp_4.csv"
early_warning = pd.read_csv(early_warning_url, sep=";")
#early_warning

# %% [markdown]
# # Reproduce Globecom

# %%
colunas = ['10_kurt_maior_pacote', '10_skw_total_ips_destino', '10_coefficient_variation_total_ips_origem' ]
init = 241
limit = 321
x_train = early_warning[colunas].copy()[init:limit]
y_real = early_warning['has_bot'][init:limit]
clustering = KMeans(n_clusters=2).fit(x_train)    
y_test = clustering.labels_
print(confusion_matrix(y_real, y_test))
print(classification_report(y_real, y_test, digits=4))
# Out:
# [[60  0]
#  [ 0 20]]
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        60
#            1     1.0000    1.0000    1.0000        20
#
#     accuracy                         1.0000        80
#    macro avg     1.0000    1.0000    1.0000        80
# weighted avg     1.0000    1.0000    1.0000        80

# %% [markdown]
# # Test FS

# %%
cols = early_warning.columns[361:]
print(cols)
init = 241
limit = 321
x_train_novo = early_warning[cols].copy()[init:limit]
y_real_novo = early_warning['has_bot'][init:limit]
x_train_novo = x_train_novo.fillna(0)
# Out:
# Index(['10_skw_total_pacotes', '10_kurt_total_pacotes',
#        '10_coefficient_variation_total_pacotes', '10_lag-1AC_total_pacotes',
#        '10_lag-2AC_total_pacotes', '10_lag-3AC_total_pacotes',
#        '10_skw_total_pacotes_icmp', '10_kurt_total_pacotes_icmp',
#        '10_coefficient_variation_total_pacotes_icmp',
#        '10_lag-1AC_total_pacotes_icmp',
#        ...
#        '10_coefficient_variation_std_tcp_time_relative',
#        '10_lag-1AC_std_tcp_time_relative', '10_lag-2AC_std_tcp_time_relative',
#        '10_lag-3AC_std_tcp_time_relative', '10_skw_mean_tcp_time_relative',
#        '10_kurt_mean_tcp_time_relative',
#        '10_coefficient_variation_mean_tcp_time_relative',
#        '10_lag-1AC_mean_tcp_time_relative',
#        '10_lag-2AC_mean_tcp_time_relative',
#        '10_lag-3AC_mean_tcp_time_relative'],
#       dtype='object', length=306)

# %%
pca = FastICA(n_components=5).fit(x_train_novo)
novo  = pca.transform(x_train_novo)

# %%
resultado3 = announce(pd.DataFrame(novo),number_clusters=2,cluster_validity_metric = 'cdbw')
pd.set_option('display.max_rows', resultado3.shape[0]+1)
resultado3
# Out:
#                                             Algorithm      cdbw
# 0                KMeans(n_clusters=2, random_state=0)  0.185849
# 1   KMeans(algorithm='full', n_clusters=2, random_...  0.185849
# 2   KMeans(algorithm='elkan', n_clusters=2, random...  0.185849
# 3   KMeans(algorithm='auto', n_clusters=2, random_...  0.185849
# 4                  Birch(n_clusters=2, threshold=0.7)  0.145425
# 5                  Birch(n_clusters=2, threshold=0.6)  0.145425
# 6                  Birch(n_clusters=2, threshold=0.4)  0.145425
# 7                  Birch(n_clusters=2, threshold=0.3)  0.145425
# 8                                 Birch(n_clusters=2)  0.145425
# 9                SOM(m=2, n=1, dim=5, random_state=0)  0.096335
# 10  KMeans(algorithm='full', n_clusters=2, n_init=...  0.091732
# 11  KMeans(algorithm='elkan', n_clusters=2, n_init...  0.091732
# 12  KMeans(algorithm='auto', n_clusters=2, n_init=...  0.091732
# 13    GaussianMixture(n_components=2, random_state=0)  0.091732
# 14  GaussianMixture(init_params='k-means++', n_com...  0.091732
# 15  GaussianMixture(covariance_type='tied', n_comp...  0.091732
# 16  GaussianMixture(covariance_type='diag', n_comp...  0.091732
# 17      BisectingKMeans(n_clusters=2, random_state=0)  0.091732
# 18  BisectingKMeans(init='k-means++', n_clusters=2...  0.091732
# 19  BisectingKMeans(bisecting_strategy='largest_cl...  0.091732
# 20  BisectingKMeans(bisecting_strategy='largest_cl...  0.091732
# 21  BisectingKMeans(algorithm='elkan', init='k-mea...  0.091732
# 22        AgglomerativeClustering(metric='euclidean')  0.091732
# 23                          AgglomerativeClustering()  0.091732
# 24  GaussianMixture(init_params='random_from_data'...  0.056538
# 25  GaussianMixture(covariance_type='spherical', n...  0.043365
# 26  GaussianMixture(init_params='random', n_compon...  0.021454
# 27                                           OPTICS()  0.000000
# 28                                        MeanShift()  0.000000
# 29                        HDBSCAN(min_cluster_size=2)  0.000000
# 30  HDBSCAN(cluster_selection_method='leaf', min_c...  0.000000
# 31                                           DBSCAN()  0.000000

# %%
print(resultado3['Algorithm'][0]) 
clustering = eval(resultado3['Algorithm'][0]) 
y_test = clustering.fit_predict(novo)  
print(confusion_matrix(y_real_novo, y_test)) 
print(classification_report(y_real_novo, y_test, digits=6))
# Out:
# KMeans(n_clusters=2, random_state=0)
# [[60  0]
#  [ 0 20]]
#               precision    recall  f1-score   support
#
#            0   1.000000  1.000000  1.000000        60
#            1   1.000000  1.000000  1.000000        20
#
#     accuracy                       1.000000        80
#    macro avg   1.000000  1.000000  1.000000        80
# weighted avg   1.000000  1.000000  1.000000        80

# %%
end = time.time()
print(end - start)
# Out:
# 0.7737903594970703

# %%
for i in range(1,10):
    print("******************************************")
    print('o valor do i é:', i)
    cols = early_warning.columns[361:]
    #print(cols)
    init = 241
    limit = 321
    x_train_novo = early_warning[cols].copy()[init:limit]
    y_real_novo = early_warning['has_bot'][init:limit]
    x_train_novo = x_train_novo.fillna(0)
    
    pca = FastICA(n_components=i).fit(x_train_novo)
    novo  = pca.transform(x_train_novo)
    
    resultado3 = announce(pd.DataFrame(novo),number_clusters=2,cluster_validity_metric = 'cdbw')
    pd.set_option('display.max_rows', resultado3.shape[0]+1)
    
    print(resultado3['Algorithm'][0]) 
    clustering = eval(resultado3['Algorithm'][0]) 
    y_test = clustering.fit_predict(novo)  
    print(confusion_matrix(y_real_novo, y_test)) 
    print(classification_report(y_real_novo, y_test, digits=6))
    print("******************************************")
# Out:
# SOM(m=2, n=1, dim=1, random_state=0)
# [[59  1]
#  [ 0 20]]
#               precision    recall  f1-score   support
#
#            0   1.000000  0.983333  0.991597        60
#            1   0.952381  1.000000  0.975610        20
#
#     accuracy                       0.987500        80
#    macro avg   0.976190  0.991667  0.983603        80
# weighted avg   0.988095  0.987500  0.987600        80
#
# GaussianMixture(init_params='random_from_data', n_components=2, random_state=0)
# [[60  0]
#  [ 0 20]]
#               precision    recall  f1-score   support
#
#            0   1.000000  1.000000  1.000000        60
#            1   1.000000  1.000000  1.000000        20
#
#     accuracy                       1.000000        80
#    macro avg   1.000000  1.000000  1.000000        80
# weighted avg   1.000000  1.000000  1.000000        80
#
# KMeans(n_clusters=2, random_state=0)
# [[60  0]
#  [ 0 20]]
#               precision    recall  f1-score   support
#
#            0   1.000000  1.000000  1.000000        60
#            1   1.000000  1.000000  1.000000        20
#
#     accuracy                       1.000000        80
#    macro avg   1.000000  1.000000  1.000000        80
# weighted avg   1.000000  1.000000  1.000000        80
#
# GaussianMixture(covariance_type='spherical', n_components=2, random_state=0)
# [[60  0]
#  [ 4 16]]
#               precision    recall  f1-score   support
#
#            0   0.937500  1.000000  0.967742        60
#            1   1.000000  0.800000  0.888889        20
#
#     accuracy                       0.950000        80
#    macro avg   0.968750  0.900000  0.928315        80
# weighted avg   0.953125  0.950000  0.948029        80
#
# KMeans(n_clusters=2, random_state=0)
# [[60  0]
#  [ 0 20]]
#               precision    recall  f1-score   support
#
#            0   1.000000  1.000000  1.000000        60
#            1   1.000000  1.000000  1.000000        20
#
#     accuracy                       1.000000        80
#    macro avg   1.000000  1.000000  1.000000        80
# weighted avg   1.000000  1.000000  1.000000        80
#
# Birch(n_clusters=2, threshold=0.7)
# [[58  2]
#  [20  0]]
#               precision    recall  f1-score   support
#
#            0   0.743590  0.966667  0.840580        60
#            1   0.000000  0.000000  0.000000        20
#
#     accuracy                       0.725000        80
#    macro avg   0.371795  0.483333  0.420290        80
# weighted avg   0.557692  0.725000  0.630435        80
#
# Birch(n_clusters=2, threshold=0.4)
# [[58  2]
#  [20  0]]
#               precision    recall  f1-score   support
#
#            0   0.743590  0.966667  0.840580        60
#            1   0.000000  0.000000  0.000000        20
#
#     accuracy                       0.725000        80
#    macro avg   0.371795  0.483333  0.420290        80
# weighted avg   0.557692  0.725000  0.630435        80
#
# KMeans(n_clusters=2, random_state=0)
# [[50 10]
#  [20  0]]
#               precision    recall  f1-score   support
#
#            0   0.714286  0.833333  0.769231        60
#            1   0.000000  0.000000  0.000000        20
#
#     accuracy                       0.625000        80
#    macro avg   0.357143  0.416667  0.384615        80
# weighted avg   0.535714  0.625000  0.576923        80
#
# KMeans(n_clusters=2, random_state=0)
# [[50 10]
#  [20  0]]
#               precision    recall  f1-score   support
#
#            0   0.714286  0.833333  0.769231        60
#            1   0.000000  0.000000  0.000000        20
#
#     accuracy                       0.625000        80
#    macro avg   0.357143  0.416667  0.384615        80
# weighted avg   0.535714  0.625000  0.576923        80
